# %% [markdown]
# # About project

# %% [markdown]
# The main goal of this project is to scrap web and get data from Amazon about best seller books. Get title, author, rating, number of users rated and price information for all available pages of products.
# Create a pandas dataframe and keep the scrapped information inside the dataframe, in separate columns.

# %% [markdown]
# # Implementation

# %%
import csv
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd

# The following function extract every single record from the html and return a tuple with everything inside.  
def extract_records(item): 
    
    atag = item.h2.a
    
    # Getting book title
    title = atag.get_text()
    
    # Getting book price, and keep it in try except block, in case if price is not written. 
    try: 
        price = item.find('span', 'a-offscreen').text
    except AttributeError:
        return
    
    # Getting book rating
    try: 
        rating = item.i.text
    except AttributeError:
        return    
    
    # Getting book author
    try: 
        author = item.find('a', 'a-size-base a-link-normal').text
    except AttributeError:
        return 
    
    # Getting number of users rated
    # Here there is a problem, as finding number is not always possible.
    # It is written in a <span> tag under tag <a>, where we can see another text as well. 
    # So I wasn't able to separate only numbers. 
    try: 
        num = item.find_all('span', 'a-size-base')[1].text
    except AttributeError:
        return
    
    # Keep all information about book in tuple. 
    result = (title, author, rating, num, price)
    
    return result

# The following function returns url for given search term. So it is possible to collect data for any search.  
def get_url(search_term):
    temp = "https://www.amazon.com/s?k={}&qid=1638647612&ref=sr_pg_1"
    search_term = search_term.replace(' ', '+')
    url = temp.format(search_term)
    url += "&page={}"
    
    return url

# I will be using search term as "best seller books" in the scope of our project.
search_term = "best seller books"

driver = webdriver.Chrome("C:\\Users\\sonaasat\\Documents\\chromedriver.exe")
url = get_url(search_term)
driver.get(url)
soup = BeautifulSoup(driver.page_source, 'html.parser')

# The following line finds all records from the html source page. 
all_records = soup.find_all("div", {'data-component-type': 's-search-result'})

# Keep all records in data list, to write it in a csv file. 
data = []
for page in range(1,7):
    driver.get(url.format(page))

    soup = BeautifulSoup(driver.page_source, 'html.parser')
    all_records = soup.find_all("div", {'data-component-type': 's-search-result'})

    for items in all_records:
        rec = extract_records(items)
        if rec: 
            data.append(rec)


driver.close()

# Creating a csv file. 
with open('data_books.csv', 'w', newline='', encoding='utf-8') as f: 
    writer = csv.writer(f)
    writer.writerow(['Title', 'Author', 'Rating','Number of users rated','Price'])
    writer.writerows(data)
# Out:
# <ipython-input-24-2f7747f70200>:58: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:\\Users\\sonaasat\\Documents\\chromedriver.exe")

# %%
import csv
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd

# %%
# I have manually modified data for "Number of users rated" column, and kept it. 
# The original data is data_books.csv
df = pd.read_csv('data.csv')

# Data pre-processing
df['Number of users rated'] = df['Number of users rated'].str.replace(',', '')
df['Number of users rated'] = pd.to_numeric(df['Number of users rated'])

df['Rating'] = df['Rating'].str.replace(' out of 5 stars', '')
df['Rating'] = pd.to_numeric(df['Rating'])

# %%
# Check, if any N/A data exists
df.isna().sum()
# Out:
# Title                    0
# Author                   0
# Rating                   0
# Number of users rated    0
# Price                    0
# dtype: int64

# %%
class Book:
    
    def __init__(self, title, author, rating, num_users_rated, price):
        """
        Create the attributes title, author, rating, num_users_rated and price
        
        Ստեղծեք title, author, rating, num_users_rated և price attribute-ները
        """
        
        self.title = title
        self.author = author
        self.rating = rating
        self.num_users_rated= num_users_rated
        self.price = price
        
    
    def pretty_print(self):
        """
        Print book information in the following format:
        $title by $author with rating $rating costs $price.
        
        Տպեք տվյալ գրքին վերաբերող ինֆորմացիան հետևյալ ֆորմատով՝
        $title by $author with rating $rating costs $price.
        """
        
        # Check if data has more than 1 book
        if len(self.title)>1: 
            info = []
            for i in range(len(self.title)):
                temp = self.title[i] + " by " + self.author[i] + ' with rating ' + str(self.rating[i]) + ' costs ' + str(self.price[i]) + '.'
                info.append(temp) 
        else: 
            info = self.title + " by " + self.author + ' with rating ' + str(self.rating) + ' costs ' + str(self.price)
        
        return info
    
    def rating_eval(self):
        """
        Evaluates the statistical significance of the rating. The method should return 
        "statistically significant rating" (or ssr) in case more than 5000 users have
        rated the following book and should return "not statistically significant rating" (or nssr), otherwise.
        
        Գնահատեք թե որքանով ստատիստիկորեն արժեքավոր է գրքին տրված գնահատականը։ Ֆունկցիան պետք է վերադարձնի 
        "statistically significant rating" (կամ ssr), եթե գիրքը գնահատել է ավելի քան 5000 օգտատեր և  
        "not statistically significant rating" (կամ nssr)՝ հակառակ դեպքում։
        """
        
        if len(self.num_users_rated)>1:
            rating_info = []
            for i in range(len(self.num_users_rated)): 
                if self.num_users_rated[i] > 5000: 
                    rating_info.append("statistically significant rating")
                else: 
                    rating_info.append("not statistically significant rating")
                
        return rating_info

# %%
book = Book(df['Title'], df["Author"], df['Rating'] , df['Number of users rated'], df['Price'])

# %%
book.pretty_print()
# Out:
# ['The Last Thing He Told Me: A Novel  by Laura Dave with rating 4.3 costs $14.00 .',
#  'Where the Crawdads Sing  by Delia Owens with rating 4.8 costs $9.98 .',
#  'Peril  by Bob Woodward with rating 4.5 costs $15.00 .',
#  'Apples Never Fall  by Kindle with rating 4.2 costs $0.00 .',
#  "The Sweetness of Water (Oprah's Book Club): A Novel  by Nathan Harris with rating 4.5 costs $14.99 .",
#  'The Stranger in the Lifeboat: A Novel  by Mitch Albom with rating 4.6 costs $14.39 .',
#  'The Wish  by Nicholas Sparks with rating 4.8 costs $14.00 .',
#  'In Five Years: A Novel  by Rebecca Serle with rating 4.4 costs $11.06 .',
#  'The Four Winds: A Novel  by Kristin Hannah with rating 4.5 costs $14.99 .',
#  'The Beekeeper of Aleppo: A Novel  by Christy Lefteri with rating 4.4 costs $8.96 .',
#  "The Judge's List: A Novel  by Kindle with rating 4.5 costs $0.00 .",
#  'A Woman of No Importance: The Untold Story of the American Spy Who Helped Win World War II  by Sonia Purnell with rating 4.6 costs $13.39 .',
#  'If You Tell: A True Story of Murder, Family Secrets, and the Unbreakable Bond of Sisterhood  by Gregg Olsen with rating 4.4 costs $11.98 .',
#  'The Last Flight: A Novel  by Julie Clark with rating 4.4 costs $9.48 .',
#  'The Couple Next Door: A Novel  by Shari Lapena with rating 4.3 costs $8.99 .',
#  "American Dirt (Oprah's Book Club): A Novel  by Hardcover with rating 4.6 costs $0.00 .",
#  'Beach Read  by Emily Henry with rating 4.4 costs $7.35 .',
#  'Spilled Milk: Based on a true story  by K.L Randis with rating 4.7 costs $12.92 .',
#  'The Book of Two Ways: A Novel  by Jodi Picoult with rating 4.1 costs $10.99 .',
#  'A Time for Mercy (Jake Brigance Book 3)  by Mass Market Paperback with rating 4.6 costs $9.99 .',
#  "The President and the Freedom Fighter: Abraham Lincoln, Frederick Douglass, and Their Battle to Save America's Soul  by Brian Kilmeade with rating 4.8 costs $17.54 .",
#  'The Midnight Library: A Novel  by Matt Haig with rating 4.3 costs $13.29 .',
#  'The Book of Longings: A Novel  by Sue Monk Kidd with rating 4.5 costs $11.50 .',
#  "When We Believed in Mermaids: A Novel  by Barbara O'Neal with rating 4.5 costs $6.69 .",
#  'The Return  by Nicholas Sparks with rating 4.6 costs $12.48 .',
#  'Pretty Things: A Novel  by Paperback with rating 4.3 costs $0.00 .',
#  'The Lincoln Highway: A Novel  by Amor Towles with rating 4.5 costs $18.28 .',
#  'State of Terror: A Novel  by Louise Penny with rating 4.5 costs $15.00 .',
#  'Between Sisters: A Novel  by Kristin Hannah with rating 4.5 costs $13.99 .',
#  'The Secrets We Keep: A gripping emotional page turner  by Kate Hewitt with rating 4.2 costs $3.99 .',
#  'Betrayal: The Final Act of the Trump Show  by Jonathan Karl with rating 4.7 costs $23.49 .',
#  'My Body  by Emily Ratajkowski with rating 4.6 costs $16.90 .',
#  'The Guardians: A Novel  by Kindle with rating 4.5 costs $0.00 .',
#  'It All Comes Back to You: A Book Club Recommendation!  by Beth Duke with rating 4.4 costs $11.68 .',
#  'Anxious People: A Novel  by Fredrik Backman with rating 4.4 costs $13.12 .',
#  "The Story of The Masters: Drama, joy and heartbreak at golf's most iconic tournament  by David Barrett with rating 4.7 costs $21.49 .",
#  'The Silent Wife: A gripping emotional page turner with a twist that will take your breath away  by Kerry Fisher with rating 4.3 costs $3.99 .',
#  'The Second Life of Mirielle West: A Haunting Historical Novel Perfect for Book Clubs  by Amanda Skenandore with rating 4.6 costs $8.27 .',
#  'Better Off Dead: A Jack Reacher Novel  by Audible Audiobook with rating 4.1 costs $14.99 .',
#  'To Rescue the Republic: Ulysses S. Grant, the Fragile Union, and the Crisis of 1876  by Bret Baier with rating 4.8 costs $17.74 .',
#  'One Little Lie: A Thrilling Suspense Novel  by Christopher Greyson with rating 4.3 costs $15.99 .',
#  'Freaking Idiots Guide To Selling On eBay: How anyone can make $100 or more everyday selling on eBay (Freaking Idiots Guides)  by Audible Audiobook with rating 4.0 costs $15.99 .',
#  'The Boys: A Memoir of Hollywood and Family  by Ron Howard with rating 4.7 costs $18.84 .',
#  'Laptop from Hell: Hunter Biden, Big Tech, and the Dirty Secrets the President Tried to Hide  by Miranda Devine with rating 4.5 costs $19.57 .',
#  'The Extraordinary Life of Sam Hell: A Novel  by Robert Dugoni with rating 4.6 costs $0.00 .',
#  'The New York Times Book Review: 125 Years of Literary History  by Kindle with rating 5.0 costs $37.63 .',
#  'The 1619 Project: A New Origin Story  by Nikole Hannah-Jones with rating 4.8 costs $23.17 .',
#  'The Greatest Beer Run Ever: A Memoir of Friendship, Loyalty, and War  by Kindle with rating 4.6 costs $14.38 .',
#  'The Silent Patient  by Hardcover with rating 4.5 costs $0.00 .',
#  "Lidia's a Pot, a Pan, and a Bowl: Simple Recipes for Perfect Meals: A Cookbook  by Tanya Bastianich Manuali with rating 4.3 costs $21.58 .",
#  "Endurance: Shackleton's Incredible Voyage  by Kindle with rating 4.8 costs $0.00 .",
#  'Vanderbilt: The Rise and Fall of an American Dynasty  by Anderson Cooper with rating 4.4 costs $18.00 .',
#  "Caste (Oprah's Book Club): The Origins of Our Discontents  by Isabel Wilkerson with rating 4.8 costs $14.79 .",
#  'Golden Girl  by Kindle with rating 4.6 costs $0.00 .',
#  'House in the Cerulean Sea  by TJ Klune with rating 4.7 costs $15.06 .',
#  'The Best of Friends  by Lucinda Berry with rating 4.3 costs $0.00 .',
#  "I Alone Can Fix It: Donald J. Trump's Catastrophic Final Year  by Philip Rucker with rating 4.7 costs $17.92 .",
#  'The Moonlight Child  by Karen McQuestion with rating 4.4 costs $0.00 .',
#  'The Last Bookshop in London: A Novel of World War II  by Madeline Martin with rating 4.5 costs $13.58 .',
#  'The Pale-Faced Lie: A True Story  by David Crow with rating 4.5 costs $13.75 .',
#  'A Promised Land  by Hardcover with rating 4.9 costs $0.00 .',
#  'The Memory of an Elephant  by Alex Lasker with rating 4.8 costs $13.99 .',
#  'The Guilty Sister: An absolutely nail-biting psychological thriller with a shocking twist  by Arianne Richmonde with rating 4.1 costs $3.99 .',
#  'Never: A Novel  by Ken Follett with rating 4.4 costs $15.99 .',
#  'Sold on a Monday: A Novel  by Kristina McMorris with rating 4.4 costs $0.00 .',
#  'Wish You Were Here: A Novel  by Jodi Picoult with rating 4.6 costs $19.88 .',
#  'On Full Automatic: Surviving 13 Months in Vietnam  by Paperback with rating 4.7 costs $0.00 .',
#  'The Pioneers: The Heroic Story of the Settlers Who Brought the American Ideal West (Thorndike Press Large Print Popular and Narrative Nonfiction)  by David McCullough with rating 4.5 costs $34.99 .',
#  'The Complete Air Fryer Cookbook for Beginners: 600 Affordable, Quick & Easy Air Fryer Recipes with Tips & Tricks to Fry, Grill, Roast, and Bake Your Favorite Daily Meals  by Kindle with rating 4.3 costs $15.99 .',
#  'The Housekeeper: A twisted psychological thriller  by Natalie Barelli with rating 4.3 costs $9.40 .',
#  'The Baseball 100  by Joe Posnanski with rating 4.8 costs $33.99 .',
#  'The Lost Girls of Ireland: A heart-warming and feel-good page-turner set in Ireland (Starlight Cottages Book 1)  by Paperback with rating 4.3 costs $2.99 .',
#  'The Missing  by Kindle with rating 4.3 costs $0.00 .',
#  'Dune  by Paperback with rating 4.7 costs $0.00 .',
#  'The Indigo Girl: A Novel  by Natasha Boyd with rating 4.6 costs $13.44 .',
#  'All American Christmas  by Rachel Campos-Duffy with rating 4.8 costs $18.92 .',
#  'We Are All the Same in the Dark: A Novel  by Paperback with rating 4.3 costs $0.00 .',
#  'The Dark Hours  by Audible Audiobook with rating 4.7 costs $14.99 .',
#  'Interesting Stories For Curious People: A Collection of Fascinating Stories About History, Science, Pop Culture and Just About Anything Else You Can Think of  by Audible Audiobook with rating 4.5 costs $8.19 .',
#  'The Case of the Murderous Dr. Cream: The Hunt for a Victorian Era Serial Killer  by Dean Jobb with rating 4.3 costs $9.44 .',
#  'What Should Darla Do? Featuring the Power to Choose (The Power to Choose Series)  by Adir Levy with rating 4.8 costs $14.84 .',
#  'The Complete Instant Pot Cookbook: 1000 Recipes For Easy & Delicious Pressure Cooker Homemade Meals  by Kindle with rating 4.8 costs $11.29 .',
#  'The Unfit Heiress: The Tragic Life and Scandalous Sterilization of Ann Cooper Hewitt  by Audrey Clare Farley with rating 4.0 costs $14.99 .',
#  'The Cellist: A Novel (Gabriel Allon Book 21)  by Audible Audiobook with rating 4.0 costs $14.99 .',
#  'The Vanishing Half: A Novel  by Kindle with rating 4.4 costs $0.00 .',
#  'Freaking Idiots Guides 4 Book Bundle Ebay Fiverr Kindle & Public Domain  by Nick Vulich with rating 4.6 costs $5.66 .',
#  'Sleigh Bells Ring: A Christmas Romance Novel  by RaeAnne Thayne with rating 4.7 costs $9.99 .',
#  'The Power of Your Subconscious Mind  by Joseph Murphy with rating 4.6 costs $5.49 .',
#  'No Way Out: A Gripping Novel of Suspense  by Fern Michaels with rating 4.1 costs $0.00 .',
#  'The Edelweiss Sisters: An epic, heartbreaking and gripping World War 2 novel  by Kate Hewitt with rating 4.5 costs $3.99 .',
#  'When the Apricots Bloom: A Novel of Riveting and Evocative Fiction  by Gina Wilkinson with rating 4.2 costs $13.58 .',
#  'The Last Green Valley: A Novel  by Mark Sullivan with rating 4.6 costs $0.00 .',
#  'Going There  by Hardcover with rating 4.4 costs $0.00 .',
#  'American Marxism  by Mark R. Levin with rating 4.9 costs $14.00 .',
#  'Pride & Prejudice (Deluxe Edition)  by Kindle with rating 4.6 costs $20.93 .',
#  'Silverview: A Novel  by John le Carré with rating 4.2 costs $14.00 .',
#  'The Perfect Wife (A Jessie Hunt Psychological Suspense Thriller—Book One)  by Paperback with rating 4.4 costs $0.00 .',
#  'The Hive  by Gregg Olsen with rating 4.0 costs $0.00 .',
#  'Winter Garden  by Kristin Hannah with rating 4.6 costs $7.56 .',
#  'The Complete Works of Jane Austen: (In One Volume) Sense and Sensibility, Pride and Prejudice, Mansfield Park, Emma, Northanger Abbey, Persuasion, Lady ... Sandition, and the Complete Juvenilia  by Jane Austen with rating 4.7 costs $2.99 .',
#  "Nala's World: One Man, His Rescue Cat, and a Bike Ride around the Globe  by Dean Nicholson with rating 4.9 costs $14.49 .",
#  'Lying Next to Me  by Gregg Olsen with rating 4.4 costs $0.00 .',
#  "The Dressmaker's Gift  by Fiona Valpy with rating 4.5 costs $8.99 .",
#  'Unspeakable Things  by Jess Lourey with rating 4.2 costs $11.99 .',
#  'The Marriage: An absolutely jaw-dropping psychological thriller  by K.L. Slater with rating 4.2 costs $3.99 .',
#  'The League: How Five Rivals Created the NFL and Launched a Sports Empire  by John Eisenberg with rating 4.6 costs $15.29 .',
#  'Then She Was Gone: A Novel  by Lisa Jewell with rating 4.6 costs $8.52 .',
#  "The Sleep Experiment: An edge-of-your-seat psychological thriller (World's Scariest Legends)  by Jeremy Bates with rating 4.3 costs $7.95 .",
#  'Fortune and Glory: Tantalizing Twenty-Seven (Stephanie Plum Book 27)  by Audible Audiobook with rating 4.6 costs $8.99 .',
#  '8 MIRACULOUS MONTHS IN THE MALAYAN JUNGLE: A WWII Pilot\'s True Story of Faith, Courage, and Survival  by Donald J. "DJ" Humphrey  II with rating 4.5 costs $15.98 .',
#  'The Sentinel: A Jack Reacher Novel  by Mass Market Paperback with rating 4.3 costs $9.99 .',
#  'The Five Wishes of Mr. Murray McBride  by Kindle with rating 4.7 costs $13.99 .',
#  'Educated: A Memoir  by Tara Westover with rating 4.7 costs $13.00 .',
#  'The Woman I Was Before: A gripping emotional page turner with a twist  by Kerry Fisher with rating 4.2 costs $3.99 .',
#  'All About Me!: My Remarkable Life in Show Business  by Mel Brooks with rating 4.5 costs $19.57 .',
#  'Our Little Secret  by Kiersten Modglin with rating 4.1 costs $0.00 .',
#  'The Boy from the Woods  by Audible Audiobook with rating 4.4 costs $11.99 .',
#  'The Locked Door: A gripping psychological thriller with a jaw-dropping twist  by Freida McFadden with rating 4.4 costs $0.00 .',
#  "Uncle Tom's Cabin  by Harriet Beecher Stowe with rating 4.6 costs $1.99 .",
#  'Up and Down: Victories and Struggles in the Course of Life  by Bubba Watson with rating 4.7 costs $20.74 .',
#  'A MIRROR ABOVE THE ABYSS: a novel  by Paperback with rating 4.4 costs $0.00 .',
#  'Before She Disappeared: A Novel (A Frankie Elkin Novel Book 1)  by Audible Audiobook with rating 4.4 costs $9.99 .',
#  'The Sanatorium: A Novel  by Sarah Pearse with rating 3.9 costs $14.83 .',
#  'AGATHA CHRISTIE Premium Collection  by Agatha Christie with rating 4.6 costs $1.99 .',
#  'Billy Summers  by Stephen King with rating 4.6 costs $15.00 .',
#  'Autopsy: A Scarpetta Novel (Kay Scarpetta, 25)  by Kindle with rating 4.6 costs $18.87 .',
#  'The Guilty Husband: An utterly gripping psychological thriller with a jaw-dropping twist!  by Stephanie DeCarolis with rating 4.3 costs $0.99 .',
#  'The Beach House (South Carolina Sunsets Book 1)  by Paperback with rating 4.3 costs $2.99 .',
#  'Night (Night)  by Audible Audiobook with rating 4.7 costs $5.49 .',
#  'Father Brown Complete Murder Mysteries: The Innocence of Father Brown, The Wisdom of Father Brown, The Donnington Affair…  by G. K. Chesterton with rating 4.2 costs $1.99 .',
#  'The Cipher (Nina Guerrera Book 1)  by Paperback with rating 4.4 costs $0.00 .',
#  "The Peacemaker's Code  by Deepak Malhotra with rating 4.7 costs $0.00 .",
#  'Cloudbuster Nine: The Untold Story of Ted Williams and the Baseball Team That Helped Win World War II  by Anne R. Keene with rating 4.6 costs $16.19 .',
#  'Extraordinary Women In History: 70 Remarkable Women Who Made a Difference, Inspired & Broke Barriers  by Leah Gail with rating 4.3 costs $0.00 .',
#  'We Were the Lucky Ones  by Kindle with rating 4.7 costs $0.00 .',
#  'The Henna Artist: A Novel (The Jaipur Trilogy Book 1)  by Audible Audiobook with rating 4.5 costs $4.99 .',
#  'The Prayer Box (A Carolina Heirlooms Novel)  by Kindle with rating 4.7 costs $9.19 .',
#  'Make $1000 Selling on eBay Before Christmas  by Kindle with rating 4.7 costs $9.99 .',
#  'The Clover Girls: A Novel  by Viola Shipman with rating 4.4 costs $9.99 .',
#  'The Best of Me  by Nicholas Sparks with rating 4.6 costs $7.48 .',
#  'Devoted  by Dean Koontz with rating 4.4 costs $10.99 .',
#  'The Venice Sketchbook: A Novel  by Rhys Bowen with rating 4.5 costs $0.00 .',
#  'The Second Mrs. Astor: A Heartbreaking Historical Novel of the Titanic  by Shana Abe with rating 4.3 costs $8.23 .',
#  'Hillbilly Elegy: A Memoir of a Family and Culture in Crisis  by Kindle with rating 4.5 costs $0.00 .',
#  "Quiet: The Power of Introverts in a World That Can't Stop Talking  by Susan Cain with rating 4.6 costs $15.33 .",
#  'City of the Dead (Maximum Ride: Hawk, 2)  by Kindle with rating 3.8 costs $14.77 .',
#  "Talking to Strangers: What We Should Know About the People We Don't Know  by Hardcover with rating 4.5 costs $0.00 .",
#  'My Encyclopedia of Very Important Things: For Little Learners Who Want to Know Everything (My Very Important Encyclopedias)  by Kindle with rating 4.8 costs $7.67 .',
#  'Fear No Evil (Alex Cross Book 29)  by Hardcover with rating 4.6 costs $14.99 .',
#  'These Tangled Vines: A Novel  by Kindle with rating 4.4 costs $0.00 .',
#  'The Christmas House: A Hickory Grove Novel  by Paperback with rating 4.4 costs $3.99 .',
#  'Little Fires Everywhere: A Novel  by Celeste Ng with rating 4.5 costs $10.20 .',
#  'The Last Rose of Shanghai: A Novel  by Weina Dai Randel with rating 4.3 costs $0.00 .',
#  '150 Most Famous Poems: Emily Dickinson, Robert Frost, William Shakespeare, Edgar Allan Poe, Walt Whitman and many more  by Poetry House with rating 4.7 costs $14.61 .',
#  'The Unofficial Masterbuilt Electric Smoker Cookbook: Ultimate Smoker Cookbook for Real Pitmasters, Includes Irresistible Meat, Fish, Poultry, Game, Vegetable Recipes for Your Electric Smoker  by Adam Jones with rating 4.9 costs $22.99 .',
#  'The Martian  by Paperback with rating 4.7 costs $0.00 .',
#  'The Guest List: A Novel  by Paperback with rating 4.2 costs $0.00 .',
#  'The Law of Innocence  by Kindle with rating 4.5 costs $0.00 .',
#  'The Last of the Moon Girls  by Barbara Davis with rating 4.4 costs $0.00 .',
#  'Extreme Ownership: How U.S. Navy SEALs Lead and Win  by Paperback with rating 4.8 costs $0.00 .',
#  'Beyond Biden: Rebuilding the America We Love  by Newt Gingrich with rating 4.7 costs $18.84 .',
#  'PIT BOSS WOOD PELLET GRILL & SMOKER COOKBOOK: 1000 Days Mouthwatering BBQ Recipes. The Ultimate Beginner-to-Pro Guide to Become the Undisputed Pitmaster of Your Neighborhood  by Steven Devon with rating 4.7 costs $0.00 .',
#  'Project Hail Mary  by Kindle with rating 4.7 costs $0.00 .',
#  'The Restaurant (The Nantucket Restaurant series Book 1)  by Paperback with rating 4.1 costs $4.99 .',
#  'It Ends with Us: A Novel  by Colleen Hoover with rating 4.7 costs $9.47 .',
#  'Blood in the Bayou: A Bone-Chilling FBI Thriller (FBI Agent Jade Monroe Live or Die Series Book 1)  by Paperback with rating 4.2 costs $0.00 .',
#  'The Last Duel: A True Story of Crime, Scandal, and Trial by Combat  by Eric Jager with rating 4.4 costs $12.99 .',
#  'The Reckoning: A Novel  by John Grisham with rating 4.2 costs $7.99 .',
#  'Leviathan Falls: Expanse, Book 9  by Kindle with rating 4.7 costs $0.00 .',
#  'The Reckoning: A Novel  by John Grisham with rating 4.2 costs $7.99 .',
#  'Flying Angels: A Novel  by Danielle Steel with rating 4.6 costs $14.49 .',
#  'Bloodline  by Jess Lourey with rating 4.2 costs $0.00 .',
#  'Sooley: A Novel  by John Grisham with rating 4.5 costs $15.67 .',
#  'While Justice Sleeps: A Novel  by Kindle with rating 4.5 costs $0.00 .',
#  'Once Upon a Chef: Weeknight/Weekend: 70 Quick-Fix Weeknight Dinners + 30 Luscious Weekend Recipes: A Cookbook  by Jennifer Segal with rating 4.9 costs $26.99 .',
#  "Clive Cussler's The Devil's Sea (Dirk Pitt Adventure Book 26)  by Audible Audiobook with rating 4.6 costs $14.99 .",
#  'Vortex: An FBI Thriller  by Hardcover with rating 4.7 costs $14.99 .',
#  'The London House  by Katherine Reay with rating 4.5 costs $9.99 .',
#  'A Wrinkle in Time (Time Quintet)  by Audible Audiobook with rating 4.6 costs $5.35 .',
#  "Where Tomorrows Aren't Promised: A Memoir of Survival and Hope  by Carmelo Anthony with rating 4.8 costs $21.09 .",
#  'The Murder on the Links (Hercule Poirot Book 2)  by Paperback with rating 4.4 costs $1.99 .',
#  'Enemy at the Gates (Mitch Rapp Book 20)  by Audible Audiobook with rating 4.6 costs $14.99 .',
#  'The Chronicles of Narnia Adult Box Set  by Paperback with rating 4.8 costs $0.00 .',
#  'My Daddy the Pedophile: A Memoir  by Paperback with rating 4.5 costs $0.00 .',
#  'The Book of Joy: Lasting Happiness in a Changing World  by Audible Audiobook with rating 4.8 costs $18.73 .',
#  'The Book of Lost Friends: A Novel  by Kindle with rating 4.5 costs $0.00 .',
#  'Talking to GOATs: The Moments You Remember and the Stories You Never Heard  by Jim Gray with rating 4.6 costs $14.59 .',
#  "Firekeeper's Daughter  by Angeline Boulley with rating 4.6 costs $10.99 .",
#  'A Little Hope: A Novel  by Ethan Joella with rating 4.2 costs $17.21 .',
#  'Elizabeth & Margaret: The Intimate World of the Windsor Sisters  by Andrew Morton with rating 4.5 costs $18.49 .',
#  'The Book Woman of Troublesome Creek: A Novel  by Kim Michele Richardson with rating 4.6 costs $7.99 .',
#  'The Family  by Naomi Krupitsky with rating 4.1 costs $17.94 .',
#  'Atlas of the Heart: Mapping Meaningful Connection and the Language of Human Experience  by Brené Brown with rating 4.4 costs $19.48 .',
#  'The Rooster Bar  by Kindle with rating 4.2 costs $0.00 .',
#  'How to Win Friends & Influence People  by Paperback with rating 4.7 costs $0.00 .',
#  'The Lost Sister: An unforgettable and heartbreaking historical timeslip novel for 2021  by Kathleen McGurl with rating 4.3 costs $0.99 .',
#  'The Girl Who Escaped from Auschwitz: A totally gripping and absolutely heartbreaking World War 2 page-turner, based on a true story  by Ellie Midwood with rating 4.6 costs $3.99 .',
#  'The Girl Who Looked Beyond The Stars (Sheena Meyer)  by Kindle with rating 4.7 costs $7.99 .',
#  'Night Road: A Novel  by Kristin Hannah with rating 4.6 costs $15.99 .',
#  'A Dance with the Fae Prince (Married to Magic)  by Paperback with rating 4.4 costs $0.00 .',
#  'The Light in Hidden Places  by Sharon Cameron with rating 4.7 costs $10.99 .',
#  'Simple Air Fryer Cookbook with Pictures: Easy Recipes for Beginners with Tips & Tricks to Fry, Grill, Roast, and Bake | Your Everyday Air Fryer Book  by Cecily Goodwin with rating 4.3 costs $17.99 .',
#  'This Tender Land (Thorndike Press Large Print Basic)  by William Kent Krueger with rating 4.6 costs $33.99 .',
#  'BAD KARMA: The True Story of a Mexico Trip from Hell  by Paul Wilson with rating 4.2 costs $12.55 .',
#  'The Other Emily  by Dean Koontz with rating 4.2 costs $12.99 .',
#  'Split Second (King & Maxwell Series Book 1)  by Audible Audiobook with rating 4.5 costs $7.99 .',
#  'Cloud Cuckoo Land: A Novel  by Anthony Doerr with rating 4.5 costs $18.57 .',
#  'The Richest Man in Babylon  by Paperback with rating 4.7 costs $0.00 .',
#  'The Girl You Killed: An addictive, heart-stopping psychological thriller (Leslie Wolfe Collection)  by Paperback with rating 4.5 costs $0.00 .',
#  'Game On: Tempting Twenty-Eight (Stephanie Plum Book 28)  by Audible Audiobook with rating 4.6 costs $15.99 .',
#  'You Are Your Best Thing: Vulnerability, Shame Resilience, and the Black Experience  by Hardcover with rating 4.8 costs $0.00 .',
#  'They Wish They Were Us  by Jessica Goodman with rating 4.3 costs $9.13 .',
#  'The Last Days of John Lennon  by James Patterson with rating 4.6 costs $14.99 .',
#  'The Book of Hope: A Survival Guide for Trying Times (Global Icons Series)  by Audible Audiobook with rating 4.8 costs $16.80 .',
#  'The Night She Disappeared: A Novel  by Kindle with rating 4.4 costs $0.00 .',
#  'The Girls in the Stilt House: A Novel  by Kelly Mustian  with rating 4.5 costs $7.39 .',
#  'The Searcher: A Novel  by Tana French with rating 4.3 costs $12.99 .',
#  'Learn to Read : Bird Saves Christmas - A Learn to Read Book for Kids 3-5: A sight words story for toddlers, kindergarten kids and preschoolers (Learn to Read Happy Bird 23)  by Paperback with rating 4.1 costs $0.00 .',
#  'A Distant Shore: A Novel  by Karen Kingsbury with rating 4.8 costs $12.99 .',
#  'People We Meet on Vacation  by Emily Henry with rating 4.3 costs $9.98 .',
#  'The Weight of Air: A Story of the Lies about Addiction and the Truth about Recovery  by David Poses with rating 4.5 costs $14.95 .',
#  'Taste: My Life Through Food  by Stanley Tucci with rating 4.7 costs $18.14 .',
#  'The Mysterious Bookshop Presents the Best Mystery Stories of the Year: 2021  by Lee Child with rating 4.2 costs $14.49 .',
#  'One Minute Out: Gray Man, Book 9  by Kindle with rating 4.6 costs $0.00 .',
#  'The School Mistress (Emerson Pass Historicals Book 1)  by Audible Audiobook with rating 4.4 costs $0.00 .',
#  'Blood and Thunder: The Epic Story of Kit Carson and the Conquest of the American West  by Hampton Sides with rating 4.7 costs $17.10 .',
#  'Unfu*k Yourself: Get Out of Your Head and into Your Life  by Hardcover with rating 4.6 costs $0.00 .',
#  'The Darkest Evening: A Vera Stanhope Novel  by Audible Audiobook with rating 4.6 costs $10.99 .',
#  "To Kill and Kill Again: The Terrifying True Story of Montana's Baby-Faced Serial Sex Murderer  by John Coston with rating 4.4 costs $18.70 .",
#  'The Becoming: The Dragon Heart Legacy, Book 2  by Hardcover with rating 4.7 costs $14.99 .',
#  'Stomp, Wiggle, Clap, and Tap: My First Book of Dance  by Rachelle Burk with rating 4.7 costs $8.57 .',
#  'Seven Perfect Things: A Novel  by Catherine Ryan Hyde with rating 4.5 costs $0.00 .',
#  'The Arrangement  by Kiersten Modglin with rating 4.2 costs $0.00 .',
#  'Facing the Mountain: A True Story of Japanese American Heroes in World War II  by Daniel James Brown with rating 4.7 costs $15.00 .',
#  "Be Right Back!: How To Overcome Your Dog's Separation Anxiety And Regain Your Freedom  by Kindle with rating 4.3 costs $12.95 .",
#  'Wildflower: A Tale of Transcendence  by Dr. Teresa Van Woy with rating 4.7 costs $0.00 .',
#  'The New Mother: A completely gripping psychological thriller with a breathtaking twist  by Julia Crouch with rating 4.1 costs $3.99 .',
#  'Renegades Born in the USA  by Barack Obama with rating 4.8 costs $30.00 .',
#  'For the Wolf  by Kindle with rating 4.2 costs $0.00 .',
#  'LA ÚLTIMA CRIPTA: La novela Nº1 en Amazon España (Las aventuras de Ulises Vidal) (Spanish Edition)  by Paperback with rating 4.1 costs $0.00 .',
#  'Open Your Eyes: The true story of an Afghan doctor who found the meaning of life by following Rumi’s philosophy of living.  by Dr. Farid Mostamand with rating 4.9 costs $0.00 .',
#  'Mercy (Atlee Pine Book 4)  by Audible Audiobook with rating 4.6 costs $14.99 .',
#  'The Thursday Murder Club: A Novel (A Thursday Murder Club Mystery Book 1)  by Audible Audiobook with rating 4.3 costs $11.99 .',
#  'Of Blood and Bone: Chronicles of The One, Book 2  by Kindle with rating 4.7 costs $0.00 .',
#  'Signs of Life Series: A Christian Fiction Thriller Series Boxed Set  by Creston Mapes with rating 4.8 costs $0.00 .',
#  'The Good Sister: A Novel  by Sally Hepworth with rating 4.4 costs $14.99 .',
#  'Effortless: Make It Easier to Do What Matters Most  by Hardcover with rating 4.6 costs $0.00 .',
#  'The Rainbow: Absolutely heartbreaking World War 2 historical fiction based on a true story  by Carly Schabowski with rating 4.5 costs $3.99 .',
#  'Sherlock Holmes: The Complete Collection  by Arthur Conan Doyle with rating 4.7 costs $2.99 .',
#  'The Killing Kind: The incredible new 2021 break-out crime thriller suspense book from the international bestselling author  by Jane Casey with rating 4.0 costs $9.99 .']

# %%
book.rating_eval()
# Out:
# ['statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating',
#  'not statistically significant rating']

# %%
import random
class Library(Book):
    
    def __init__(self,title, author, rating, num_users_rated, price):
        """
        Create an attribute of type list called Book_list which will be an empty list for now.
        
        Ստեղծեք list տիպի Book_list attribute-ը, որն առայժմ կլինի դատարկ list 
        """
        
        Book_list = []
        self.Book_list = Book_list
        
        self.title = title
        self.author = author
        self.rating = rating
        self.num_users_rated= num_users_rated
        self.price = price
    
    def get_top_5(self):
        """
        Return the information related to 5 books that have the highest rating using the method pretty_print.
        If there are more than 5 books with the same rating, randomly select and show only 5 of them.
        
        Վերադարձրեք 5 ամենաբարձր գնահատական ունեցող գրքերի վերաբերյալ ինֆորմացիա՝ օգտվելով pretty_print
        ֆունկցիայից։ Եթե այդպիսի գրքերը 5-ից ավելի են՝ պատահականության սկզբունքով ընտրեք դրանցից 5-ը։
        """
        
        df_sorted = df.sort_values(by=['Rating'], ascending=False)
        df_sorted = df_sorted.reset_index()  
        
        book = Book(df_sorted['Title'], df_sorted["Author"], df_sorted['Rating'] , df_sorted['Number of users rated'], df_sorted['Price'])
        
        b = list(Book.pretty_print(book))
        
        k=0
        
        while k<5:
            print("Top %d: " %(k+1), b[k])
            print("-------------------------")
            k +=1
            
        return print("Top 5 rated books are being printed!")   
    
    def simple_search(self, title):
        """
        Search a book with required title and print information related to all books with titles exactly 
        matching the searched title using the method pretty_print.
        
        Search արեք տրված վերնագրով գիրք (գրքեր) և վերադարձրեք այդ գրքի (գրքերի) մասին ինֆորմացիան՝ օգտվելով 
        pretty_print ֆունկցիայից։ Վերադարձված գրքերի վերնագրերը պետք է համընկնեն title փոփոխականի արժեքի հետ
        """
        
        book = Book(df['Title'], df["Author"], df['Rating'] , df['Number of users rated'], df['Price'])
        
        b = list(Book.pretty_print(book))
        
        matched_books = []
        
        for i in range(len(df['Title'])):
            if title == df['Title'][i]:
                matched_books.append(b[i])
        
        
        return matched_books
    
    def complex_search(self, title):
        """
        In this case the user may not remember the exact title of the book. If you have a book(s) with 
        title exactly matching the searched title, this method should perform just like the method simple_search.
        Otherwise, if you don't have any books with the searched title, you should return book(s) that have the
        most similar titles. You are free to implement this method however you like. 
        One version that you can implement in case you don't have other ideas:
        return the book(s) with titles containing the most number of words from the searched title 
        (return the information using the method pretty_print), and if there are no such books, 
        return "nothing macthed your search".
        I would be happy to see any other interesting versions of the method :)
        
        
        Այս դեպքում օգտատերը միգուցե չհիշի գրքի կոնկրետ անվանումը կամ այն մի փոքր սխալ հիշի։ Եթե կա գիրք (գրքեր)
        որոնց վերնագիրը համընկնում է title փոփոխականի արժեքի հետ, ապա վերադարձրեք այդ գրքին (գրքերին) 
        վերաբերող ինֆորմացիան՝ օգտվելով pretty_print ֆունկցիայից։ Հակառակ դեպքում, պետք է վերադարձնել այն գրքերի մասին 
        ինֆորմացիա, որոնց վերնագրերը նման են title փոփոխականում պահված վերնագրի արժեքին։ Ազատ եք
        որոշելու այս ֆունկցիայի աշխատանքի տրամաբանությունը։
        Որպես հնարավոր տարբերակ (եթե չկան այլ մտքեր) կարող եք վերադարձնել այն գրքերի ինֆորմացին, որոնց
        վերնագրերը պարունակում են title փոփոխամանում տրված բառերից ամենաշատ քանակության բառերը ու եթե չկան
        այդպիսի գրքեր, վերադարձրեք "nothing macthed your search"։ 
        Ուրախ կլինեմ տեսնել այս ֆունկցիայի հետաքրքիր տարբերակներ :)
        """
        
        book = Book(df['Title'], df["Author"], df['Rating'] , df['Number of users rated'], df['Price'])
        
        b = list(Book.pretty_print(book))
        
        exact_matched_books = []
        
        for i in range(len(df['Title'])):
            if title == df['Title'][i]:
                exact_matched_books.append(b[i])
        
        if len(exact_matched_books)==0:
            match_books_contained_str = []
            for i in range(len(df['Title'])):
                # Handle uppercase and lowercase
                if title.lower() in df['Title'][i].lower():
                    match_books_contained_str.append(b[i])
            
            if len(match_books_contained_str)>0: 
                return match_books_contained_str
            else: 
                books_with_similar_name = []
                
                # Implement of complex search               
                for i in range(len(df['Title'])):
                    # Following line intersect 2 strings, and by this way algorithm will find matching books according to intersection. 
                    # As a condition, script checks if more than 8 characters are matching, return that book using pretty_print() method. 
                    res = ''.join(sorted(set(title) & set(df['Title'][i]), key = title.index)) 
                    if len(res)>8:
                        books_with_similar_name.append(b[i])
                
                
                if len(books_with_similar_name)>0:
                    return books_with_similar_name
                else: 
                    return print("Nothing matched your search. Try anything else.")
            
            return match_books_contained_str
            
        elif len(exact_matched_books)>0:
            return exact_matched_books

# %%
lib = Library(df['Title'], df["Author"], df['Rating'] , df['Number of users rated'], df['Price'])

# %%
lib.get_top_5()
# Out:
# Top 1:  The New York Times Book Review: 125 Years of Literary History  by Kindle with rating 5.0 costs $37.63 .
# -------------------------
# Top 2:  The Unofficial Masterbuilt Electric Smoker Cookbook: Ultimate Smoker Cookbook for Real Pitmasters, Includes Irresistible Meat, Fish, Poultry, Game, Vegetable Recipes for Your Electric Smoker  by Adam Jones with rating 4.9 costs $22.99 .
# -------------------------
# Top 3:  American Marxism  by Mark R. Levin with rating 4.9 costs $14.00 .
# -------------------------
# Top 4:  Nala's World: One Man, His Rescue Cat, and a Bike Ride around the Globe  by Dean Nicholson with rating 4.9 costs $14.49 .
# -------------------------
# Top 5:  Open Your Eyes: The true story of an Afghan doctor who found the meaning of life by following Rumi’s philosophy of living.  by Dr. Farid Mostamand with rating 4.9 costs $0.00 .
# -------------------------
# Top 5 rated books are being printed!

# %%
df_sorted = df.sort_values(by=['Rating'], ascending=False)
df_sorted = df_sorted.reset_index()

# %%
df_sorted.head(10)
# Out:
#    index                                              Title  \
# 0     45  The New York Times Book Review: 125 Years of L...
# 1    154  The Unofficial Masterbuilt Electric Smoker Coo...
# 2     93                                  American Marxism
# 3    100  Nala's World: One Man, His Rescue Cat, and a B...
# 4    240  Open Your Eyes: The true story of an Afghan do...
# 5    174  Once Upon a Chef: Weeknight/Weekend: 70 Quick-...
# 6     60                                   A Promised Land
# 7     46              The 1619 Project: A New Origin Story
# 8    244  Signs of Life Series: A Christian Fiction Thri...
# 9    159  Extreme Ownership: How U.S. Navy SEALs Lead an...
#
#                 Author  Rating  Number of users rated    Price
# 0               Kindle     5.0                   6828  $37.63
# 1           Adam Jones     4.9                      9  $22.99
# 2        Mark R. Levin     4.9                  21806  $14.00
# 3       Dean Nicholson     4.9                  27900  $14.49
# 4  Dr. Farid Mostamand     4.9                     32   $0.00
# 5       Jennifer Segal     4.9                    652  $26.99
# 6            Hardcover     4.9                   4366   $0.00
# 7  Nikole Hannah-Jones     4.8                   2027  $23.17
# 8        Creston Mapes     4.8                     92   $0.00
# 9            Paperback     4.8                  12069   $0.00

# %%
lib.simple_search("American Marxism ")
# Out:
# ['American Marxism  by Mark R. Levin with rating 4.9 costs $14.00 .']

# %%
lib.complex_search("American")
# Out:
# ['A Woman of No Importance: The Untold Story of the American Spy Who Helped Win World War II  by Sonia Purnell with rating 4.6 costs $13.39 .',
#  "American Dirt (Oprah's Book Club): A Novel  by Hardcover with rating 4.6 costs $0.00 .",
#  'Vanderbilt: The Rise and Fall of an American Dynasty  by Anderson Cooper with rating 4.4 costs $18.00 .',
#  'The Pioneers: The Heroic Story of the Settlers Who Brought the American Ideal West (Thorndike Press Large Print Popular and Narrative Nonfiction)  by David McCullough with rating 4.5 costs $34.99 .',
#  'All American Christmas  by Rachel Campos-Duffy with rating 4.8 costs $18.92 .',
#  'American Marxism  by Mark R. Levin with rating 4.9 costs $14.00 .',
#  'Blood and Thunder: The Epic Story of Kit Carson and the Conquest of the American West  by Hampton Sides with rating 4.7 costs $17.10 .',
#  'Facing the Mountain: A True Story of Japanese American Heroes in World War II  by Daniel James Brown with rating 4.7 costs $15.00 .']

# %%
lib.complex_search("Marxism")
# Out:
# ['American Marxism  by Mark R. Levin with rating 4.9 costs $14.00 .']

# %%
lib.complex_search("novel")
# Out:
# ['The Last Thing He Told Me: A Novel  by Laura Dave with rating 4.3 costs $14.00 .',
#  "The Sweetness of Water (Oprah's Book Club): A Novel  by Nathan Harris with rating 4.5 costs $14.99 .",
#  'The Stranger in the Lifeboat: A Novel  by Mitch Albom with rating 4.6 costs $14.39 .',
#  'In Five Years: A Novel  by Rebecca Serle with rating 4.4 costs $11.06 .',
#  'The Four Winds: A Novel  by Kristin Hannah with rating 4.5 costs $14.99 .',
#  'The Beekeeper of Aleppo: A Novel  by Christy Lefteri with rating 4.4 costs $8.96 .',
#  "The Judge's List: A Novel  by Kindle with rating 4.5 costs $0.00 .",
#  'The Last Flight: A Novel  by Julie Clark with rating 4.4 costs $9.48 .',
#  'The Couple Next Door: A Novel  by Shari Lapena with rating 4.3 costs $8.99 .',
#  "American Dirt (Oprah's Book Club): A Novel  by Hardcover with rating 4.6 costs $0.00 .",
#  'The Book of Two Ways: A Novel  by Jodi Picoult with rating 4.1 costs $10.99 .',
#  'The Midnight Library: A Novel  by Matt Haig with rating 4.3 costs $13.29 .',
#  'The Book of Longings: A Novel  by Sue Monk Kidd with rating 4.5 costs $11.50 .',
#  "When We Believed in Mermaids: A Novel  by Barbara O'Neal with rating 4.5 costs $6.69 .",
#  'Pretty Things: A Novel  by Paperback with rating 4.3 costs $0.00 .',
#  'The Lincoln Highway: A Novel  by Amor Towles with rating 4.5 costs $18.28 .',
#  'State of Terror: A Novel  by Louise Penny with rating 4.5 costs $15.00 .',
#  'Between Sisters: A Novel  by Kristin Hannah with rating 4.5 costs $13.99 .',
#  'The Guardians: A Novel  by Kindle with rating 4.5 costs $0.00 .',
#  'Anxious People: A Novel  by Fredrik Backman with rating 4.4 costs $13.12 .',
#  'The Second Life of Mirielle West: A Haunting Historical Novel Perfect for Book Clubs  by Amanda Skenandore with rating 4.6 costs $8.27 .',
#  'Better Off Dead: A Jack Reacher Novel  by Audible Audiobook with rating 4.1 costs $14.99 .',
#  'One Little Lie: A Thrilling Suspense Novel  by Christopher Greyson with rating 4.3 costs $15.99 .',
#  'The Extraordinary Life of Sam Hell: A Novel  by Robert Dugoni with rating 4.6 costs $0.00 .',
#  'The Last Bookshop in London: A Novel of World War II  by Madeline Martin with rating 4.5 costs $13.58 .',
#  'Never: A Novel  by Ken Follett with rating 4.4 costs $15.99 .',
#  'Sold on a Monday: A Novel  by Kristina McMorris with rating 4.4 costs $0.00 .',
#  'Wish You Were Here: A Novel  by Jodi Picoult with rating 4.6 costs $19.88 .',
#  'The Indigo Girl: A Novel  by Natasha Boyd with rating 4.6 costs $13.44 .',
#  'We Are All the Same in the Dark: A Novel  by Paperback with rating 4.3 costs $0.00 .',
#  'The Cellist: A Novel (Gabriel Allon Book 21)  by Audible Audiobook with rating 4.0 costs $14.99 .',
#  'The Vanishing Half: A Novel  by Kindle with rating 4.4 costs $0.00 .',
#  'Sleigh Bells Ring: A Christmas Romance Novel  by RaeAnne Thayne with rating 4.7 costs $9.99 .',
#  'No Way Out: A Gripping Novel of Suspense  by Fern Michaels with rating 4.1 costs $0.00 .',
#  'The Edelweiss Sisters: An epic, heartbreaking and gripping World War 2 novel  by Kate Hewitt with rating 4.5 costs $3.99 .',
#  'When the Apricots Bloom: A Novel of Riveting and Evocative Fiction  by Gina Wilkinson with rating 4.2 costs $13.58 .',
#  'The Last Green Valley: A Novel  by Mark Sullivan with rating 4.6 costs $0.00 .',
#  'Silverview: A Novel  by John le Carré with rating 4.2 costs $14.00 .',
#  'Then She Was Gone: A Novel  by Lisa Jewell with rating 4.6 costs $8.52 .',
#  'The Sentinel: A Jack Reacher Novel  by Mass Market Paperback with rating 4.3 costs $9.99 .',
#  'A MIRROR ABOVE THE ABYSS: a novel  by Paperback with rating 4.4 costs $0.00 .',
#  'Before She Disappeared: A Novel (A Frankie Elkin Novel Book 1)  by Audible Audiobook with rating 4.4 costs $9.99 .',
#  'The Sanatorium: A Novel  by Sarah Pearse with rating 3.9 costs $14.83 .',
#  'Autopsy: A Scarpetta Novel (Kay Scarpetta, 25)  by Kindle with rating 4.6 costs $18.87 .',
#  'The Henna Artist: A Novel (The Jaipur Trilogy Book 1)  by Audible Audiobook with rating 4.5 costs $4.99 .',
#  'The Prayer Box (A Carolina Heirlooms Novel)  by Kindle with rating 4.7 costs $9.19 .',
#  'The Clover Girls: A Novel  by Viola Shipman with rating 4.4 costs $9.99 .',
#  'The Venice Sketchbook: A Novel  by Rhys Bowen with rating 4.5 costs $0.00 .',
#  'The Second Mrs. Astor: A Heartbreaking Historical Novel of the Titanic  by Shana Abe with rating 4.3 costs $8.23 .',
#  'These Tangled Vines: A Novel  by Kindle with rating 4.4 costs $0.00 .',
#  'The Christmas House: A Hickory Grove Novel  by Paperback with rating 4.4 costs $3.99 .',
#  'Little Fires Everywhere: A Novel  by Celeste Ng with rating 4.5 costs $10.20 .',
#  'The Last Rose of Shanghai: A Novel  by Weina Dai Randel with rating 4.3 costs $0.00 .',
#  'The Guest List: A Novel  by Paperback with rating 4.2 costs $0.00 .',
#  'It Ends with Us: A Novel  by Colleen Hoover with rating 4.7 costs $9.47 .',
#  'The Reckoning: A Novel  by John Grisham with rating 4.2 costs $7.99 .',
#  'The Reckoning: A Novel  by John Grisham with rating 4.2 costs $7.99 .',
#  'Flying Angels: A Novel  by Danielle Steel with rating 4.6 costs $14.49 .',
#  'Sooley: A Novel  by John Grisham with rating 4.5 costs $15.67 .',
#  'While Justice Sleeps: A Novel  by Kindle with rating 4.5 costs $0.00 .',
#  'The Book of Lost Friends: A Novel  by Kindle with rating 4.5 costs $0.00 .',
#  'A Little Hope: A Novel  by Ethan Joella with rating 4.2 costs $17.21 .',
#  'The Book Woman of Troublesome Creek: A Novel  by Kim Michele Richardson with rating 4.6 costs $7.99 .',
#  'The Lost Sister: An unforgettable and heartbreaking historical timeslip novel for 2021  by Kathleen McGurl with rating 4.3 costs $0.99 .',
#  'Night Road: A Novel  by Kristin Hannah with rating 4.6 costs $15.99 .',
#  'Cloud Cuckoo Land: A Novel  by Anthony Doerr with rating 4.5 costs $18.57 .',
#  'The Night She Disappeared: A Novel  by Kindle with rating 4.4 costs $0.00 .',
#  'The Girls in the Stilt House: A Novel  by Kelly Mustian  with rating 4.5 costs $7.39 .',
#  'The Searcher: A Novel  by Tana French with rating 4.3 costs $12.99 .',
#  'A Distant Shore: A Novel  by Karen Kingsbury with rating 4.8 costs $12.99 .',
#  'The Darkest Evening: A Vera Stanhope Novel  by Audible Audiobook with rating 4.6 costs $10.99 .',
#  'Seven Perfect Things: A Novel  by Catherine Ryan Hyde with rating 4.5 costs $0.00 .',
#  'LA ÚLTIMA CRIPTA: La novela Nº1 en Amazon España (Las aventuras de Ulises Vidal) (Spanish Edition)  by Paperback with rating 4.1 costs $0.00 .',
#  'The Thursday Murder Club: A Novel (A Thursday Murder Club Mystery Book 1)  by Audible Audiobook with rating 4.3 costs $11.99 .',
#  'The Good Sister: A Novel  by Sally Hepworth with rating 4.4 costs $14.99 .']

# %%
lib.complex_search("novel")
# Out:
# ['The Last Thing He Told Me: A Novel  by Laura Dave with rating 4.3 costs $14.00 .',
#  "The Sweetness of Water (Oprah's Book Club): A Novel  by Nathan Harris with rating 4.5 costs $14.99 .",
#  'The Stranger in the Lifeboat: A Novel  by Mitch Albom with rating 4.6 costs $14.39 .',
#  'In Five Years: A Novel  by Rebecca Serle with rating 4.4 costs $11.06 .',
#  'The Four Winds: A Novel  by Kristin Hannah with rating 4.5 costs $14.99 .',
#  'The Beekeeper of Aleppo: A Novel  by Christy Lefteri with rating 4.4 costs $8.96 .',
#  "The Judge's List: A Novel  by Kindle with rating 4.5 costs $0.00 .",
#  'The Last Flight: A Novel  by Julie Clark with rating 4.4 costs $9.48 .',
#  'The Couple Next Door: A Novel  by Shari Lapena with rating 4.3 costs $8.99 .',
#  "American Dirt (Oprah's Book Club): A Novel  by Hardcover with rating 4.6 costs $0.00 .",
#  'The Book of Two Ways: A Novel  by Jodi Picoult with rating 4.1 costs $10.99 .',
#  'The Midnight Library: A Novel  by Matt Haig with rating 4.3 costs $13.29 .',
#  'The Book of Longings: A Novel  by Sue Monk Kidd with rating 4.5 costs $11.50 .',
#  "When We Believed in Mermaids: A Novel  by Barbara O'Neal with rating 4.5 costs $6.69 .",
#  'Pretty Things: A Novel  by Paperback with rating 4.3 costs $0.00 .',
#  'The Lincoln Highway: A Novel  by Amor Towles with rating 4.5 costs $18.28 .',
#  'State of Terror: A Novel  by Louise Penny with rating 4.5 costs $15.00 .',
#  'Between Sisters: A Novel  by Kristin Hannah with rating 4.5 costs $13.99 .',
#  'The Guardians: A Novel  by Kindle with rating 4.5 costs $0.00 .',
#  'Anxious People: A Novel  by Fredrik Backman with rating 4.4 costs $13.12 .',
#  'The Second Life of Mirielle West: A Haunting Historical Novel Perfect for Book Clubs  by Amanda Skenandore with rating 4.6 costs $8.27 .',
#  'Better Off Dead: A Jack Reacher Novel  by Audible Audiobook with rating 4.1 costs $14.99 .',
#  'One Little Lie: A Thrilling Suspense Novel  by Christopher Greyson with rating 4.3 costs $15.99 .',
#  'The Extraordinary Life of Sam Hell: A Novel  by Robert Dugoni with rating 4.6 costs $0.00 .',
#  'The Last Bookshop in London: A Novel of World War II  by Madeline Martin with rating 4.5 costs $13.58 .',
#  'Never: A Novel  by Ken Follett with rating 4.4 costs $15.99 .',
#  'Sold on a Monday: A Novel  by Kristina McMorris with rating 4.4 costs $0.00 .',
#  'Wish You Were Here: A Novel  by Jodi Picoult with rating 4.6 costs $19.88 .',
#  'The Indigo Girl: A Novel  by Natasha Boyd with rating 4.6 costs $13.44 .',
#  'We Are All the Same in the Dark: A Novel  by Paperback with rating 4.3 costs $0.00 .',
#  'The Cellist: A Novel (Gabriel Allon Book 21)  by Audible Audiobook with rating 4.0 costs $14.99 .',
#  'The Vanishing Half: A Novel  by Kindle with rating 4.4 costs $0.00 .',
#  'Sleigh Bells Ring: A Christmas Romance Novel  by RaeAnne Thayne with rating 4.7 costs $9.99 .',
#  'No Way Out: A Gripping Novel of Suspense  by Fern Michaels with rating 4.1 costs $0.00 .',
#  'The Edelweiss Sisters: An epic, heartbreaking and gripping World War 2 novel  by Kate Hewitt with rating 4.5 costs $3.99 .',
#  'When the Apricots Bloom: A Novel of Riveting and Evocative Fiction  by Gina Wilkinson with rating 4.2 costs $13.58 .',
#  'The Last Green Valley: A Novel  by Mark Sullivan with rating 4.6 costs $0.00 .',
#  'Silverview: A Novel  by John le Carré with rating 4.2 costs $14.00 .',
#  'Then She Was Gone: A Novel  by Lisa Jewell with rating 4.6 costs $8.52 .',
#  'The Sentinel: A Jack Reacher Novel  by Mass Market Paperback with rating 4.3 costs $9.99 .',
#  'A MIRROR ABOVE THE ABYSS: a novel  by Paperback with rating 4.4 costs $0.00 .',
#  'Before She Disappeared: A Novel (A Frankie Elkin Novel Book 1)  by Audible Audiobook with rating 4.4 costs $9.99 .',
#  'The Sanatorium: A Novel  by Sarah Pearse with rating 3.9 costs $14.83 .',
#  'Autopsy: A Scarpetta Novel (Kay Scarpetta, 25)  by Kindle with rating 4.6 costs $18.87 .',
#  'The Henna Artist: A Novel (The Jaipur Trilogy Book 1)  by Audible Audiobook with rating 4.5 costs $4.99 .',
#  'The Prayer Box (A Carolina Heirlooms Novel)  by Kindle with rating 4.7 costs $9.19 .',
#  'The Clover Girls: A Novel  by Viola Shipman with rating 4.4 costs $9.99 .',
#  'The Venice Sketchbook: A Novel  by Rhys Bowen with rating 4.5 costs $0.00 .',
#  'The Second Mrs. Astor: A Heartbreaking Historical Novel of the Titanic  by Shana Abe with rating 4.3 costs $8.23 .',
#  'These Tangled Vines: A Novel  by Kindle with rating 4.4 costs $0.00 .',
#  'The Christmas House: A Hickory Grove Novel  by Paperback with rating 4.4 costs $3.99 .',
#  'Little Fires Everywhere: A Novel  by Celeste Ng with rating 4.5 costs $10.20 .',
#  'The Last Rose of Shanghai: A Novel  by Weina Dai Randel with rating 4.3 costs $0.00 .',
#  'The Guest List: A Novel  by Paperback with rating 4.2 costs $0.00 .',
#  'It Ends with Us: A Novel  by Colleen Hoover with rating 4.7 costs $9.47 .',
#  'The Reckoning: A Novel  by John Grisham with rating 4.2 costs $7.99 .',
#  'The Reckoning: A Novel  by John Grisham with rating 4.2 costs $7.99 .',
#  'Flying Angels: A Novel  by Danielle Steel with rating 4.6 costs $14.49 .',
#  'Sooley: A Novel  by John Grisham with rating 4.5 costs $15.67 .',
#  'While Justice Sleeps: A Novel  by Kindle with rating 4.5 costs $0.00 .',
#  'The Book of Lost Friends: A Novel  by Kindle with rating 4.5 costs $0.00 .',
#  'A Little Hope: A Novel  by Ethan Joella with rating 4.2 costs $17.21 .',
#  'The Book Woman of Troublesome Creek: A Novel  by Kim Michele Richardson with rating 4.6 costs $7.99 .',
#  'The Lost Sister: An unforgettable and heartbreaking historical timeslip novel for 2021  by Kathleen McGurl with rating 4.3 costs $0.99 .',
#  'Night Road: A Novel  by Kristin Hannah with rating 4.6 costs $15.99 .',
#  'Cloud Cuckoo Land: A Novel  by Anthony Doerr with rating 4.5 costs $18.57 .',
#  'The Night She Disappeared: A Novel  by Kindle with rating 4.4 costs $0.00 .',
#  'The Girls in the Stilt House: A Novel  by Kelly Mustian  with rating 4.5 costs $7.39 .',
#  'The Searcher: A Novel  by Tana French with rating 4.3 costs $12.99 .',
#  'A Distant Shore: A Novel  by Karen Kingsbury with rating 4.8 costs $12.99 .',
#  'The Darkest Evening: A Vera Stanhope Novel  by Audible Audiobook with rating 4.6 costs $10.99 .',
#  'Seven Perfect Things: A Novel  by Catherine Ryan Hyde with rating 4.5 costs $0.00 .',
#  'LA ÚLTIMA CRIPTA: La novela Nº1 en Amazon España (Las aventuras de Ulises Vidal) (Spanish Edition)  by Paperback with rating 4.1 costs $0.00 .',
#  'The Thursday Murder Club: A Novel (A Thursday Murder Club Mystery Book 1)  by Audible Audiobook with rating 4.3 costs $11.99 .',
#  'The Good Sister: A Novel  by Sally Hepworth with rating 4.4 costs $14.99 .']

# %%
lib.complex_search("life")
# Out:
# ['The Stranger in the Lifeboat: A Novel  by Mitch Albom with rating 4.6 costs $14.39 .',
#  'The Second Life of Mirielle West: A Haunting Historical Novel Perfect for Book Clubs  by Amanda Skenandore with rating 4.6 costs $8.27 .',
#  'The Extraordinary Life of Sam Hell: A Novel  by Robert Dugoni with rating 4.6 costs $0.00 .',
#  'The Unfit Heiress: The Tragic Life and Scandalous Sterilization of Ann Cooper Hewitt  by Audrey Clare Farley with rating 4.0 costs $14.99 .',
#  'All About Me!: My Remarkable Life in Show Business  by Mel Brooks with rating 4.5 costs $19.57 .',
#  'Up and Down: Victories and Struggles in the Course of Life  by Bubba Watson with rating 4.7 costs $20.74 .',
#  'Taste: My Life Through Food  by Stanley Tucci with rating 4.7 costs $18.14 .',
#  'Unfu*k Yourself: Get Out of Your Head and into Your Life  by Hardcover with rating 4.6 costs $0.00 .',
#  'Open Your Eyes: The true story of an Afghan doctor who found the meaning of life by following Rumi’s philosophy of living.  by Dr. Farid Mostamand with rating 4.9 costs $0.00 .',
#  'Signs of Life Series: A Christian Fiction Thriller Series Boxed Set  by Creston Mapes with rating 4.8 costs $0.00 .']

# %%
len(lib.complex_search("game of chess"))
# Out:
# 55

# %%
lib.complex_search("game of chess")
# Out:
# ['If You Tell: A True Story of Murder, Family Secrets, and the Unbreakable Bond of Sisterhood  by Gregg Olsen with rating 4.4 costs $11.98 .',
#  "The President and the Freedom Fighter: Abraham Lincoln, Frederick Douglass, and Their Battle to Save America's Soul  by Brian Kilmeade with rating 4.8 costs $17.54 .",
#  'The Secrets We Keep: A gripping emotional page turner  by Kate Hewitt with rating 4.2 costs $3.99 .',
#  "The Story of The Masters: Drama, joy and heartbreak at golf's most iconic tournament  by David Barrett with rating 4.7 costs $21.49 .",
#  'The Silent Wife: A gripping emotional page turner with a twist that will take your breath away  by Kerry Fisher with rating 4.3 costs $3.99 .',
#  'The Second Life of Mirielle West: A Haunting Historical Novel Perfect for Book Clubs  by Amanda Skenandore with rating 4.6 costs $8.27 .',
#  'To Rescue the Republic: Ulysses S. Grant, the Fragile Union, and the Crisis of 1876  by Bret Baier with rating 4.8 costs $17.74 .',
#  'Laptop from Hell: Hunter Biden, Big Tech, and the Dirty Secrets the President Tried to Hide  by Miranda Devine with rating 4.5 costs $19.57 .',
#  'Vanderbilt: The Rise and Fall of an American Dynasty  by Anderson Cooper with rating 4.4 costs $18.00 .',
#  "Caste (Oprah's Book Club): The Origins of Our Discontents  by Isabel Wilkerson with rating 4.8 costs $14.79 .",
#  'On Full Automatic: Surviving 13 Months in Vietnam  by Paperback with rating 4.7 costs $0.00 .',
#  'The Pioneers: The Heroic Story of the Settlers Who Brought the American Ideal West (Thorndike Press Large Print Popular and Narrative Nonfiction)  by David McCullough with rating 4.5 costs $34.99 .',
#  'The Complete Air Fryer Cookbook for Beginners: 600 Affordable, Quick & Easy Air Fryer Recipes with Tips & Tricks to Fry, Grill, Roast, and Bake Your Favorite Daily Meals  by Kindle with rating 4.3 costs $15.99 .',
#  'The Lost Girls of Ireland: A heart-warming and feel-good page-turner set in Ireland (Starlight Cottages Book 1)  by Paperback with rating 4.3 costs $2.99 .',
#  'Interesting Stories For Curious People: A Collection of Fascinating Stories About History, Science, Pop Culture and Just About Anything Else You Can Think of  by Audible Audiobook with rating 4.5 costs $8.19 .',
#  'The Case of the Murderous Dr. Cream: The Hunt for a Victorian Era Serial Killer  by Dean Jobb with rating 4.3 costs $9.44 .',
#  'The Unfit Heiress: The Tragic Life and Scandalous Sterilization of Ann Cooper Hewitt  by Audrey Clare Farley with rating 4.0 costs $14.99 .',
#  'Sleigh Bells Ring: A Christmas Romance Novel  by RaeAnne Thayne with rating 4.7 costs $9.99 .',
#  'When the Apricots Bloom: A Novel of Riveting and Evocative Fiction  by Gina Wilkinson with rating 4.2 costs $13.58 .',
#  'The Perfect Wife (A Jessie Hunt Psychological Suspense Thriller—Book One)  by Paperback with rating 4.4 costs $0.00 .',
#  'The Complete Works of Jane Austen: (In One Volume) Sense and Sensibility, Pride and Prejudice, Mansfield Park, Emma, Northanger Abbey, Persuasion, Lady ... Sandition, and the Complete Juvenilia  by Jane Austen with rating 4.7 costs $2.99 .',
#  'The League: How Five Rivals Created the NFL and Launched a Sports Empire  by John Eisenberg with rating 4.6 costs $15.29 .',
#  "The Sleep Experiment: An edge-of-your-seat psychological thriller (World's Scariest Legends)  by Jeremy Bates with rating 4.3 costs $7.95 .",
#  'The Woman I Was Before: A gripping emotional page turner with a twist  by Kerry Fisher with rating 4.2 costs $3.99 .',
#  'Up and Down: Victories and Struggles in the Course of Life  by Bubba Watson with rating 4.7 costs $20.74 .',
#  'Father Brown Complete Murder Mysteries: The Innocence of Father Brown, The Wisdom of Father Brown, The Donnington Affair…  by G. K. Chesterton with rating 4.2 costs $1.99 .',
#  'Extraordinary Women In History: 70 Remarkable Women Who Made a Difference, Inspired & Broke Barriers  by Leah Gail with rating 4.3 costs $0.00 .',
#  'Make $1000 Selling on eBay Before Christmas  by Kindle with rating 4.7 costs $9.99 .',
#  'The Second Mrs. Astor: A Heartbreaking Historical Novel of the Titanic  by Shana Abe with rating 4.3 costs $8.23 .',
#  'My Encyclopedia of Very Important Things: For Little Learners Who Want to Know Everything (My Very Important Encyclopedias)  by Kindle with rating 4.8 costs $7.67 .',
#  '150 Most Famous Poems: Emily Dickinson, Robert Frost, William Shakespeare, Edgar Allan Poe, Walt Whitman and many more  by Poetry House with rating 4.7 costs $14.61 .',
#  'The Unofficial Masterbuilt Electric Smoker Cookbook: Ultimate Smoker Cookbook for Real Pitmasters, Includes Irresistible Meat, Fish, Poultry, Game, Vegetable Recipes for Your Electric Smoker  by Adam Jones with rating 4.9 costs $22.99 .',
#  'PIT BOSS WOOD PELLET GRILL & SMOKER COOKBOOK: 1000 Days Mouthwatering BBQ Recipes. The Ultimate Beginner-to-Pro Guide to Become the Undisputed Pitmaster of Your Neighborhood  by Steven Devon with rating 4.7 costs $0.00 .',
#  'The Last Duel: A True Story of Crime, Scandal, and Trial by Combat  by Eric Jager with rating 4.4 costs $12.99 .',
#  'Once Upon a Chef: Weeknight/Weekend: 70 Quick-Fix Weeknight Dinners + 30 Luscious Weekend Recipes: A Cookbook  by Jennifer Segal with rating 4.9 costs $26.99 .',
#  'Elizabeth & Margaret: The Intimate World of the Windsor Sisters  by Andrew Morton with rating 4.5 costs $18.49 .',
#  'Atlas of the Heart: Mapping Meaningful Connection and the Language of Human Experience  by Brené Brown with rating 4.4 costs $19.48 .',
#  'The Lost Sister: An unforgettable and heartbreaking historical timeslip novel for 2021  by Kathleen McGurl with rating 4.3 costs $0.99 .',
#  'The Girl Who Escaped from Auschwitz: A totally gripping and absolutely heartbreaking World War 2 page-turner, based on a true story  by Ellie Midwood with rating 4.6 costs $3.99 .',
#  'Simple Air Fryer Cookbook with Pictures: Easy Recipes for Beginners with Tips & Tricks to Fry, Grill, Roast, and Bake | Your Everyday Air Fryer Book  by Cecily Goodwin with rating 4.3 costs $17.99 .',
#  'The Girl You Killed: An addictive, heart-stopping psychological thriller (Leslie Wolfe Collection)  by Paperback with rating 4.5 costs $0.00 .',
#  'You Are Your Best Thing: Vulnerability, Shame Resilience, and the Black Experience  by Hardcover with rating 4.8 costs $0.00 .',
#  'The Book of Hope: A Survival Guide for Trying Times (Global Icons Series)  by Audible Audiobook with rating 4.8 costs $16.80 .',
#  'Learn to Read : Bird Saves Christmas - A Learn to Read Book for Kids 3-5: A sight words story for toddlers, kindergarten kids and preschoolers (Learn to Read Happy Bird 23)  by Paperback with rating 4.1 costs $0.00 .',
#  'The Weight of Air: A Story of the Lies about Addiction and the Truth about Recovery  by David Poses with rating 4.5 costs $14.95 .',
#  'Blood and Thunder: The Epic Story of Kit Carson and the Conquest of the American West  by Hampton Sides with rating 4.7 costs $17.10 .',
#  "To Kill and Kill Again: The Terrifying True Story of Montana's Baby-Faced Serial Sex Murderer  by John Coston with rating 4.4 costs $18.70 .",
#  'Stomp, Wiggle, Clap, and Tap: My First Book of Dance  by Rachelle Burk with rating 4.7 costs $8.57 .',
#  'Facing the Mountain: A True Story of Japanese American Heroes in World War II  by Daniel James Brown with rating 4.7 costs $15.00 .',
#  "Be Right Back!: How To Overcome Your Dog's Separation Anxiety And Regain Your Freedom  by Kindle with rating 4.3 costs $12.95 .",
#  'The New Mother: A completely gripping psychological thriller with a breathtaking twist  by Julia Crouch with rating 4.1 costs $3.99 .',
#  'Open Your Eyes: The true story of an Afghan doctor who found the meaning of life by following Rumi’s philosophy of living.  by Dr. Farid Mostamand with rating 4.9 costs $0.00 .',
#  'Signs of Life Series: A Christian Fiction Thriller Series Boxed Set  by Creston Mapes with rating 4.8 costs $0.00 .',
#  'The Rainbow: Absolutely heartbreaking World War 2 historical fiction based on a true story  by Carly Schabowski with rating 4.5 costs $3.99 .',
#  'The Killing Kind: The incredible new 2021 break-out crime thriller suspense book from the international bestselling author  by Jane Casey with rating 4.0 costs $9.99 .']

# %%
lib.complex_search("love")
# Out:
# ['The Clover Girls: A Novel  by Viola Shipman with rating 4.4 costs $9.99 .',
#  'Beyond Biden: Rebuilding the America We Love  by Newt Gingrich with rating 4.7 costs $18.84 .']

# %%
lib.complex_search("love story")
# Out:
# ['Pretty Things: A Novel  by Paperback with rating 4.3 costs $0.00 .',
#  'Freaking Idiots Guide To Selling On eBay: How anyone can make $100 or more everyday selling on eBay (Freaking Idiots Guides)  by Audible Audiobook with rating 4.0 costs $15.99 .',
#  'The Greatest Beer Run Ever: A Memoir of Friendship, Loyalty, and War  by Kindle with rating 4.6 costs $14.38 .',
#  'The Pioneers: The Heroic Story of the Settlers Who Brought the American Ideal West (Thorndike Press Large Print Popular and Narrative Nonfiction)  by David McCullough with rating 4.5 costs $34.99 .',
#  'The Complete Air Fryer Cookbook for Beginners: 600 Affordable, Quick & Easy Air Fryer Recipes with Tips & Tricks to Fry, Grill, Roast, and Bake Your Favorite Daily Meals  by Kindle with rating 4.3 costs $15.99 .',
#  'Freaking Idiots Guides 4 Book Bundle Ebay Fiverr Kindle & Public Domain  by Nick Vulich with rating 4.6 costs $5.66 .',
#  'No Way Out: A Gripping Novel of Suspense  by Fern Michaels with rating 4.1 costs $0.00 .',
#  'The Last Green Valley: A Novel  by Mark Sullivan with rating 4.6 costs $0.00 .',
#  'The Complete Works of Jane Austen: (In One Volume) Sense and Sensibility, Pride and Prejudice, Mansfield Park, Emma, Northanger Abbey, Persuasion, Lady ... Sandition, and the Complete Juvenilia  by Jane Austen with rating 4.7 costs $2.99 .',
#  '8 MIRACULOUS MONTHS IN THE MALAYAN JUNGLE: A WWII Pilot\'s True Story of Faith, Courage, and Survival  by Donald J. "DJ" Humphrey  II with rating 4.5 costs $15.98 .',
#  'Autopsy: A Scarpetta Novel (Kay Scarpetta, 25)  by Kindle with rating 4.6 costs $18.87 .',
#  'The Henna Artist: A Novel (The Jaipur Trilogy Book 1)  by Audible Audiobook with rating 4.5 costs $4.99 .',
#  'My Encyclopedia of Very Important Things: For Little Learners Who Want to Know Everything (My Very Important Encyclopedias)  by Kindle with rating 4.8 costs $7.67 .',
#  'The Christmas House: A Hickory Grove Novel  by Paperback with rating 4.4 costs $3.99 .',
#  'Little Fires Everywhere: A Novel  by Celeste Ng with rating 4.5 costs $10.20 .',
#  'Blood in the Bayou: A Bone-Chilling FBI Thriller (FBI Agent Jade Monroe Live or Die Series Book 1)  by Paperback with rating 4.2 costs $0.00 .',
#  'Simple Air Fryer Cookbook with Pictures: Easy Recipes for Beginners with Tips & Tricks to Fry, Grill, Roast, and Bake | Your Everyday Air Fryer Book  by Cecily Goodwin with rating 4.3 costs $17.99 .',
#  'The Girl You Killed: An addictive, heart-stopping psychological thriller (Leslie Wolfe Collection)  by Paperback with rating 4.5 costs $0.00 .',
#  'Learn to Read : Bird Saves Christmas - A Learn to Read Book for Kids 3-5: A sight words story for toddlers, kindergarten kids and preschoolers (Learn to Read Happy Bird 23)  by Paperback with rating 4.1 costs $0.00 .',
#  'Open Your Eyes: The true story of an Afghan doctor who found the meaning of life by following Rumi’s philosophy of living.  by Dr. Farid Mostamand with rating 4.9 costs $0.00 .',
#  'The Thursday Murder Club: A Novel (A Thursday Murder Club Mystery Book 1)  by Audible Audiobook with rating 4.3 costs $11.99 .']

# %% [markdown]
# # Summary

# %% [markdown]
# I have used webdriver module from selenium package for scrapping.
# Then I have added a function "get_url", which can be used for generating url for any search (not only for "best seller books").
# And in the end, data have been stored in csv file.

# %% [markdown]
# For second task, mainly implemented 2 search algorithms: first one (simple_search) returns exactly matching books, and the second one(complex_search), returns those books, which user might mean. The algorithm implementation is based on number of characters appears in both strings, and if it is more than 8, book name will be exported.

# %% [markdown]
# And in the end some experiments were being done to check logic of script.

# %% [markdown]
# Thanks for this project! It was very very helpful.
